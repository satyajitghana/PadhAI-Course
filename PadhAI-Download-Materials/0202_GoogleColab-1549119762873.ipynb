# %% [markdown]
# # Section 1
# Simple Linux commands

# %%
# !ls
# Out:
# sample_data

# %%
# !ls
# Out:
# sample_data

# %%
# !cat /proc/cpuinfo

# %%
# !cat /proc/meminfo

# %% [markdown]
# This is a text cell, where I can write in **bold**
# I can also write in $\LaTeX$

# %% [markdown]
# # Section 2
# Moving on to Python
